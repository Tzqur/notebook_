# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Introduction
# Welcome to this introductory notebook on Data Science! In this notebook, we will explore some of the fundamental tools, languages, and libraries that are commonly used in the field of data science. This notebook is designed to give you a basic overview and understanding of the data science ecosystem. We will also practice some basic coding exercises to demonstrate arithmetic operations and time conversion.

# %% [markdown]
# ## Data Science Languages
# Data scientists utilize a variety of programming languages to perform data analysis, build models, and derive insights. Some of the most popular data science languages include:
#
# 1.  Python
# 2.  R
# 3.  SQL
# 4.  Scala
# 5.  Julia
# 6.  Java
# 7.  C++

# %% [markdown]
# ## Data Science Libraries
# Data science relies heavily on specialized libraries that provide pre-built functions and tools for various tasks. Here are some of the most widely used libraries in Python:
#
# 1.  NumPy
# 2.  Pandas
# 3.  Scikit-learn
# 4.  TensorFlow
# 5.  Keras
# 6.  PyTorch
# 7.  Matplotlib
# 8.  Seaborn
# 9.  Statsmodels
# 10. NLTK
# 11. spaCy
# 12. OpenCV

# %% [markdown]
# ## Data Science Tools
# | Tool             | Description                                                                                                         |
# | :--------------- | :------------------------------------------------------------------------------------------------------------------ |
# | Jupyter Notebook | Interactive web-based environment for creating and sharing documents that contain live code, equations, visualizations |
# | RStudio          | IDE for R programming, providing tools for statistical computing, data analysis, and visualization                    |
# | Apache Spark     | Unified analytics engine for big data processing, offering libraries for SQL, machine learning, and graph processing |
# | Hadoop           | Framework for distributed storage and processing of large datasets across clusters of computers                        |
# | Tableau          | Data visualization tool for creating interactive dashboards and reports                                             |
# | Power BI         | Business analytics service by Microsoft, providing interactive visualizations and business intelligence capabilities   |
# | KNIME            | Open-source data analytics platform for creating and executing data science workflows                                 |
# | RapidMiner       | Data science platform for building and deploying machine learning models

# %% [markdown]
# ## Arithmetic Expression Examples
# Below are a few examples of evaluating arithmetic expressions in Python:

# %%
# Multiply two numbers
num1 = 10
num2 = 5
product = num1 * num2
print(f"The product of {num1} and {num2} is: {product}")

# Add two numbers
sum_result = num1 + num2
print(f"The sum of {num1} and {num2} is: {sum_result}")

# %%
# Convert minutes to hours
minutes = 150
hours = minutes / 60
print(f"{minutes} minutes is equal to {hours} hours")

# %% [markdown]
# ## Objectives
# *   Explore fundamental data science languages and libraries.
# *   Understand the role of various data science tools.
# *   Practice basic arithmetic operations in Python.
# *   Learn how to convert units of time using Python.
# *   Gain familiarity with creating and formatting Markdown cells in a Jupyter Notebook.
# *   Provide an overview of common tools used in the data science ecosystem.
# *   Practice basic coding exercises in Python.

# %% [markdown]
# ## Author
# Taylan Keskin
